# %% [markdown]
# # Exploratory analysis

# %%
# Initial imports
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# %matplotlib inline

import pydotplus
from IPython.display import Image

# %%
# Import csv file with tweets for elon musk
file_name='final_data_frame.csv'
file_path=Path(f"../Resources/{file_name}")
tweets_df = pd.read_csv(file_path, parse_dates=True, infer_datetime_format=True)
tweets_df.rename(columns={'Unnamed: 0': 'date' }, inplace=True)
tweets_df.set_index('date', inplace=True)
tweets_df.head()
# Out:
#              TSLA        QQQ  Y_d1_pr_change_diff  Y_d5_pr_change_diff  \
# date
# 2010-06-29  4.778  39.031284                  NaN                  NaN
# 2010-06-30  4.766  38.437302             0.012707                  NaN
# 2010-07-01  4.392  38.329292            -0.075662                  NaN
# 2010-07-02  3.840  38.221321            -0.122866                  NaN
# 2010-07-06  3.222  38.338306            -0.163998                  NaN
#
#             quarterly report announcement flag  tweet count  number likes  \
# date
# 2010-06-29                                 0.0          0.0           0.0
# 2010-06-30                                 0.0          0.0           0.0
# 2010-07-01                                 0.0          0.0           0.0
# 2010-07-02                                 0.0          0.0           0.0
# 2010-07-06                                 0.0          0.0           0.0
#
#             number replies  number retweets clean  compound  ...  mars  time  \
# date                                                         ...
# 2010-06-29             0.0                    0.0       0.0  ...     0     0
# 2010-06-30             0.0                    0.0       0.0  ...     0     0
# 2010-07-01             0.0                    0.0       0.0  ...     0     0
# 2010-07-02             0.0                    0.0       0.0  ...     0     0
# 2010-07-06             0.0                    0.0       0.0  ...     0     0
#
#             rocket  engine  soon  tesla  spacex  keyword strength  \
# date
# 2010-06-29       0       0     0      0       0                 0
# 2010-06-30       0       0     0      0       0                 0
# 2010-07-01       0       0     0      0       0                 0
# 2010-07-02       0       0     0      0       0                 0
# 2010-07-06       0       0     0      0       0                 0
#
#             keyword flag  tweet flag
# date
# 2010-06-29             0           0
# 2010-06-30             0           0
# 2010-07-01             0           0
# 2010-07-02             0           0
# 2010-07-06             0           0
#
# [5 rows x 44 columns]

# %%
tweets_df.columns
# Out:
# Index(['TSLA', 'QQQ', 'Y_d1_pr_change_diff', 'Y_d5_pr_change_diff',
#        'quarterly report announcement flag', 'tweet count', 'number likes',
#        'number replies', 'number retweets clean', 'compound', 'positive',
#        'negative', 'neutral', 'sentiment', 'model 3', 'coming soon',
#        'next week', 'next year', 'falcon 9', 'falcon heavy', 'model x',
#        'next month', 'space station', 'sustainable energy', 'electric car',
#        'climate change', 'software update', 'dual motor', 'self-driving',
#        'giga berlin', 'solar power', 'launch', 'production', 'starship',
#        'mars', 'time', 'rocket', 'engine', 'soon', 'tesla', 'spacex',
#        'keyword strength', 'keyword flag', 'tweet flag'],
#       dtype='object')

# %%
tweets_df.iloc[:, 14:41].columns
# Out:
# Index(['model 3', 'coming soon', 'next week', 'next year', 'falcon 9',
#        'falcon heavy', 'model x', 'next month', 'space station',
#        'sustainable energy', 'electric car', 'climate change',
#        'software update', 'dual motor', 'self-driving', 'giga berlin',
#        'solar power', 'launch', 'production', 'starship', 'mars', 'time',
#        'rocket', 'engine', 'soon', 'tesla', 'spacex'],
#       dtype='object')

# %%
tweets_df['positive'].value_counts()
# Out:
# 0.000    1373
# 0.161      11
# 0.178      10
# 0.208      10
# 0.112      10
#          ...
# 0.086       1
# 0.357       1
# 0.548       1
# 0.540       1
# 0.289       1
# Name: positive, Length: 410, dtype: int64

# %%
tweets_df['negative'].value_counts()
# Out:
# 0.000    1737
# 0.054      14
# 0.049      14
# 0.058      14
# 0.057      14
#          ...
# 0.292       1
# 0.147       1
# 0.158       1
# 0.236       1
# 0.306       1
# Name: negative, Length: 211, dtype: int64

# %%
engage_df = tweets_df.iloc[:, 5:9]
engage_df.plot(figsize=(20,8), fontsize=15, subplots=True, colormap='Spectral_r', title="Twitter Engagement")
stock_df1 = tweets_df[['TSLA', 'QQQ']]
stock_df1.plot(figsize=(20,3), title = "TSLA & QQQ closing price", colormap='brg', fontsize=15)

# %%
engage_df['2019-09-01':].plot(figsize=(20,8), title = "Twitter Engagement",
                             colormap='Spectral_r', fontsize=15, subplots=True, grid=True)
stock_df1['2019-09-01':].plot(figsize=(20,3), title="TSLA & QQQ closing price", colormap='brg', fontsize=15, grid=True)

# %%
sent_df = tweets_df[['compound', 'positive','negative', 'neutral', 'TSLA','QQQ']]
sent_df
# Out:
#             compound  positive  negative  neutral        TSLA         QQQ
# date
# 2010-06-29    0.0000     0.000     0.000    0.000    4.778000   39.031284
# 2010-06-30    0.0000     0.000     0.000    0.000    4.766000   38.437302
# 2010-07-01    0.0000     0.000     0.000    0.000    4.392000   38.329292
# 2010-07-02    0.0000     0.000     0.000    0.000    3.840000   38.221321
# 2010-07-06    0.0000     0.000     0.000    0.000    3.222000   38.338306
# ...              ...       ...       ...      ...         ...         ...
# 2021-01-13    0.5226     0.141     0.090    0.769  854.409973  316.040009
# 2021-01-14    0.9357     0.336     0.120    0.545  845.000000  314.350006
# 2021-01-15    0.9429     0.182     0.000    0.818  826.159973  311.859985
# 2021-01-19    0.9980     0.316     0.031    0.653  844.549988  316.410004
# 2021-01-20    0.0000     0.000     0.000    0.000  850.450012  323.769989
#
# [2659 rows x 6 columns]

# %%
# correlation heatmap
fig, ax = plt.subplots(figsize=(15, 10))  
sns.heatmap(sent_df.corr(), annot=True, linewidth=0.5, ax=ax, square=True)

# %%
sent_df1 = tweets_df[['compound','negative', 'positive', 'neutral']]
print(sent_df1.head(3))
stock_df1 = tweets_df[['TSLA', 'QQQ']]
print(stock_df1.head(3))
# Out:
#             compound  negative  positive  neutral
# date
# 2010-06-29       0.0       0.0       0.0      0.0
# 2010-06-30       0.0       0.0       0.0      0.0
# 2010-07-01       0.0       0.0       0.0      0.0
#              TSLA        QQQ
# date
# 2010-06-29  4.778  39.031284
# 2010-06-30  4.766  38.437302
# 2010-07-01  4.392  38.329292

# %%
sent_df1.plot(y = ['compound', 'negative', 'positive', 'neutral'], figsize=(20,8), title = "Twitter Sentiment", 
              colormap='viridis', fontsize=15, subplots=True, ylim=(0,1) )
stock_df1.plot(figsize=(20,3), title = "TSLA & QQQ closing price", colormap='brg',fontsize=15)

# %%
sent_df1['2019-09-01':].plot(y=['compound', 'negative', 'positive', 'neutral'], figsize=(20,8), title = "Twitter Sentiment",
                             colormap='viridis', fontsize=15, subplots=True, grid=True, ylim=(0,1))
stock_df1['2019-09-01':].plot(figsize=(20,3), title="TSLA & QQQ closing price", colormap='brg', fontsize=15, grid=True)

# %% [markdown]
# # Random Forests

# %%
# Import csv file with tweets for elon musk
file_name='final_data_frame.csv'
file_path=Path(f"../Resources/{file_name}")
tweets_df = pd.read_csv(file_path, parse_dates=True, infer_datetime_format=True)
tweets_df.rename(columns={'Unnamed: 0': 'date' }, inplace=True)
tweets_df.set_index('date', inplace=True)
tweets_df
# Out:
#                   TSLA         QQQ  Y_d1_pr_change_diff  Y_d5_pr_change_diff  \
# date
# 2010-06-29    4.778000   39.031284                  NaN                  NaN
# 2010-06-30    4.766000   38.437302             0.012707                  NaN
# 2010-07-01    4.392000   38.329292            -0.075662                  NaN
# 2010-07-02    3.840000   38.221321            -0.122866                  NaN
# 2010-07-06    3.222000   38.338306            -0.163998                  NaN
# ...                ...         ...                  ...                  ...
# 2021-01-13  854.409973  316.040009            -0.000902             0.102563
# 2021-01-14  845.000000  314.350006            -0.005666             0.037489
# 2021-01-15  826.159973  311.859985            -0.014375            -0.038729
# 2021-01-19  844.549988  316.410004             0.007670             0.034796
# 2021-01-20  850.450012  323.769989            -0.016275            -0.030188
#
#             quarterly report announcement flag  tweet count  number likes  \
# date
# 2010-06-29                                 0.0          0.0           0.0
# 2010-06-30                                 0.0          0.0           0.0
# 2010-07-01                                 0.0          0.0           0.0
# 2010-07-02                                 0.0          0.0           0.0
# 2010-07-06                                 0.0          0.0           0.0
# ...                                        ...          ...           ...
# 2021-01-13                                 0.0         11.0     1734427.0
# 2021-01-14                                 0.0          7.0      559632.0
# 2021-01-15                                 0.0         11.0      169339.0
# 2021-01-19                                 0.0         18.0      453510.0
# 2021-01-20                                 0.0          0.0           0.0
#
#             number replies  number retweets clean  compound  ...  mars  time  \
# date                                                         ...
# 2010-06-29             0.0                    0.0    0.0000  ...     0     0
# 2010-06-30             0.0                    0.0    0.0000  ...     0     0
# 2010-07-01             0.0                    0.0    0.0000  ...     0     0
# 2010-07-02             0.0                    0.0    0.0000  ...     0     0
# 2010-07-06             0.0                    0.0    0.0000  ...     0     0
# ...                    ...                    ...       ...  ...   ...   ...
# 2021-01-13         40100.0               213435.0    0.5226  ...     1     0
# 2021-01-14         14544.0                38701.0    0.9357  ...     1     0
# 2021-01-15          9381.0                12439.0    0.9429  ...     0     0
# 2021-01-19         14856.0                19635.0    0.9980  ...     0     0
# 2021-01-20             0.0                    0.0    0.0000  ...     0     0
#
#             rocket  engine  soon  tesla  spacex  keyword strength  \
# date
# 2010-06-29       0       0     0      0       0                 0
# 2010-06-30       0       0     0      0       0                 0
# 2010-07-01       0       0     0      0       0                 0
# 2010-07-02       0       0     0      0       0                 0
# 2010-07-06       0       0     0      0       0                 0
# ...            ...     ...   ...    ...     ...               ...
# 2021-01-13       0       1     0      0       1                 4
# 2021-01-14       0       0     0      0       0                 2
# 2021-01-15       0       1     0      0       0                 1
# 2021-01-19       0       0     0      0       0                 2
# 2021-01-20       0       0     0      0       0                 0
#
#             keyword flag  tweet flag
# date
# 2010-06-29             0           0
# 2010-06-30             0           0
# 2010-07-01             0           0
# 2010-07-02             0           0
# 2010-07-06             0           0
# ...                  ...         ...
# 2021-01-13             1           1
# 2021-01-14             1           1
# 2021-01-15             1           1
# 2021-01-19             1           1
# 2021-01-20             0           0
#
# [2659 rows x 44 columns]

# %%
tweets_df.head(7)
# Out:
#              TSLA        QQQ  Y_d1_pr_change_diff  Y_d5_pr_change_diff  \
# date
# 2010-06-29  4.778  39.031284                  NaN                  NaN
# 2010-06-30  4.766  38.437302             0.012707                  NaN
# 2010-07-01  4.392  38.329292            -0.075662                  NaN
# 2010-07-02  3.840  38.221321            -0.122866                  NaN
# 2010-07-06  3.222  38.338306            -0.163998                  NaN
# 2010-07-07  3.160  39.562256            -0.051168            -0.352239
# 2010-07-08  3.492  39.778240             0.099604            -0.302196
#
#             quarterly report announcement flag  tweet count  number likes  \
# date
# 2010-06-29                                 0.0          0.0           0.0
# 2010-06-30                                 0.0          0.0           0.0
# 2010-07-01                                 0.0          0.0           0.0
# 2010-07-02                                 0.0          0.0           0.0
# 2010-07-06                                 0.0          0.0           0.0
# 2010-07-07                                 0.0          0.0           0.0
# 2010-07-08                                 0.0          0.0           0.0
#
#             number replies  number retweets clean  compound  ...  mars  time  \
# date                                                         ...
# 2010-06-29             0.0                    0.0       0.0  ...     0     0
# 2010-06-30             0.0                    0.0       0.0  ...     0     0
# 2010-07-01             0.0                    0.0       0.0  ...     0     0
# 2010-07-02             0.0                    0.0       0.0  ...     0     0
# 2010-07-06             0.0                    0.0       0.0  ...     0     0
# 2010-07-07             0.0                    0.0       0.0  ...     0     0
# 2010-07-08             0.0                    0.0       0.0  ...     0     0
#
#             rocket  engine  soon  tesla  spacex  keyword strength  \
# date
# 2010-06-29       0       0     0      0       0                 0
# 2010-06-30       0       0     0      0       0                 0
# 2010-07-01       0       0     0      0       0                 0
# 2010-07-02       0       0     0      0       0                 0
# 2010-07-06       0       0     0      0       0                 0
# 2010-07-07       0       0     0      0       0                 0
# 2010-07-08       0       0     0      0       0                 0
#
#             keyword flag  tweet flag
# date
# 2010-06-29             0           0
# 2010-06-30             0           0
# 2010-07-01             0           0
# 2010-07-02             0           0
# 2010-07-06             0           0
# 2010-07-07             0           0
# 2010-07-08             0           0
#
# [7 rows x 44 columns]

# %%
dropped_na_df = tweets_df.iloc[5:, :]
dropped_na_df
# Out:
#                   TSLA         QQQ  Y_d1_pr_change_diff  Y_d5_pr_change_diff  \
# date
# 2010-07-07    3.160000   39.562256            -0.051168            -0.352239
# 2010-07-08    3.492000   39.778240             0.099604            -0.302196
# 2010-07-09    3.480000   40.156231            -0.012939            -0.255315
# 2010-07-12    3.410000   40.273220            -0.023028            -0.165664
# 2010-07-13    3.628000   40.795197             0.050969             0.061924
# ...                ...         ...                  ...                  ...
# 2021-01-13  854.409973  316.040009            -0.000902             0.102563
# 2021-01-14  845.000000  314.350006            -0.005666             0.037489
# 2021-01-15  826.159973  311.859985            -0.014375            -0.038729
# 2021-01-19  844.549988  316.410004             0.007670             0.034796
# 2021-01-20  850.450012  323.769989            -0.016275            -0.030188
#
#             quarterly report announcement flag  tweet count  number likes  \
# date
# 2010-07-07                                 0.0          0.0           0.0
# 2010-07-08                                 0.0          0.0           0.0
# 2010-07-09                                 0.0          0.0           0.0
# 2010-07-12                                 0.0          0.0           0.0
# 2010-07-13                                 0.0          0.0           0.0
# ...                                        ...          ...           ...
# 2021-01-13                                 0.0         11.0     1734427.0
# 2021-01-14                                 0.0          7.0      559632.0
# 2021-01-15                                 0.0         11.0      169339.0
# 2021-01-19                                 0.0         18.0      453510.0
# 2021-01-20                                 0.0          0.0           0.0
#
#             number replies  number retweets clean  compound  ...  mars  time  \
# date                                                         ...
# 2010-07-07             0.0                    0.0    0.0000  ...     0     0
# 2010-07-08             0.0                    0.0    0.0000  ...     0     0
# 2010-07-09             0.0                    0.0    0.0000  ...     0     0
# 2010-07-12             0.0                    0.0    0.0000  ...     0     0
# 2010-07-13             0.0                    0.0    0.0000  ...     0     0
# ...                    ...                    ...       ...  ...   ...   ...
# 2021-01-13         40100.0               213435.0    0.5226  ...     1     0
# 2021-01-14         14544.0                38701.0    0.9357  ...     1     0
# 2021-01-15          9381.0                12439.0    0.9429  ...     0     0
# 2021-01-19         14856.0                19635.0    0.9980  ...     0     0
# 2021-01-20             0.0                    0.0    0.0000  ...     0     0
#
#             rocket  engine  soon  tesla  spacex  keyword strength  \
# date
# 2010-07-07       0       0     0      0       0                 0
# 2010-07-08       0       0     0      0       0                 0
# 2010-07-09       0       0     0      0       0                 0
# 2010-07-12       0       0     0      0       0                 0
# 2010-07-13       0       0     0      0       0                 0
# ...            ...     ...   ...    ...     ...               ...
# 2021-01-13       0       1     0      0       1                 4
# 2021-01-14       0       0     0      0       0                 2
# 2021-01-15       0       1     0      0       0                 1
# 2021-01-19       0       0     0      0       0                 2
# 2021-01-20       0       0     0      0       0                 0
#
#             keyword flag  tweet flag
# date
# 2010-07-07             0           0
# 2010-07-08             0           0
# 2010-07-09             0           0
# 2010-07-12             0           0
# 2010-07-13             0           0
# ...                  ...         ...
# 2021-01-13             1           1
# 2021-01-14             1           1
# 2021-01-15             1           1
# 2021-01-19             1           1
# 2021-01-20             0           0
#
# [2654 rows x 44 columns]

# %%
# Define features set
X = dropped_na_df.copy()
X = dropped_na_df.iloc[:, 4:]
X.head()
# Out:
#             quarterly report announcement flag  tweet count  number likes  \
# date
# 2010-07-07                                 0.0          0.0           0.0
# 2010-07-08                                 0.0          0.0           0.0
# 2010-07-09                                 0.0          0.0           0.0
# 2010-07-12                                 0.0          0.0           0.0
# 2010-07-13                                 0.0          0.0           0.0
#
#             number replies  number retweets clean  compound  positive  \
# date
# 2010-07-07             0.0                    0.0       0.0       0.0
# 2010-07-08             0.0                    0.0       0.0       0.0
# 2010-07-09             0.0                    0.0       0.0       0.0
# 2010-07-12             0.0                    0.0       0.0       0.0
# 2010-07-13             0.0                    0.0       0.0       0.0
#
#             negative  neutral  sentiment  ...  mars  time  rocket  engine  \
# date                                      ...
# 2010-07-07       0.0      0.0          0  ...     0     0       0       0
# 2010-07-08       0.0      0.0          0  ...     0     0       0       0
# 2010-07-09       0.0      0.0          0  ...     0     0       0       0
# 2010-07-12       0.0      0.0          0  ...     0     0       0       0
# 2010-07-13       0.0      0.0          0  ...     0     0       0       0
#
#             soon  tesla  spacex  keyword strength  keyword flag  tweet flag
# date
# 2010-07-07     0      0       0                 0             0           0
# 2010-07-08     0      0       0                 0             0           0
# 2010-07-09     0      0       0                 0             0           0
# 2010-07-12     0      0       0                 0             0           0
# 2010-07-13     0      0       0                 0             0           0
#
# [5 rows x 40 columns]

# %%
X.columns
# Out:
# Index(['quarterly report announcement flag', 'tweet count', 'number likes',
#        'number replies', 'number retweets clean', 'compound', 'positive',
#        'negative', 'neutral', 'sentiment', 'model 3', 'coming soon',
#        'next week', 'next year', 'falcon 9', 'falcon heavy', 'model x',
#        'next month', 'space station', 'sustainable energy', 'electric car',
#        'climate change', 'software update', 'dual motor', 'self-driving',
#        'giga berlin', 'solar power', 'launch', 'production', 'starship',
#        'mars', 'time', 'rocket', 'engine', 'soon', 'tesla', 'spacex',
#        'keyword strength', 'keyword flag', 'tweet flag'],
#       dtype='object')

# %%
# Define target vector
#y = tweets_df["col"].values.reshape(-1, 1)
y = dropped_na_df["Y_d5_pr_change_diff"].ravel()
y
# Out:
# array([-0.35223912, -0.30219645, -0.2553146 , ..., -0.03872879,
#         0.03479567, -0.03018831])

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# only `X_train` and `X_testing` DataFrames should be scaled
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaler
X_scaler = scaler.fit(X_train)
X_scaler
# Out:
# StandardScaler()

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled)
X_scaled = X_scaler.transform(X)
X_scaled = pd.DataFrame(X_scaled)
X_scaled
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
# 1    -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
# 2    -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
# 3    -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
# 4    -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
# ...        ...       ...       ...       ...       ...       ...       ...
# 2649 -0.123718  0.743113  7.069661  5.130107  7.511413  0.485031  0.237406
# 2650 -0.123718  0.285883  2.041136  1.651866  1.085101  1.406721  1.556066
# 2651 -0.123718  0.743113  0.370548  0.949168  0.119245  1.422785  0.514663
# 2652 -0.123718  1.543265  1.586898  1.694330  0.383897  1.545722  1.420818
# 2653 -0.123718 -0.514269 -0.354280 -0.327611 -0.338233 -0.680971 -0.716086
#
#             7         8         9   ...        30       31        32  \
# 0    -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
# 1    -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
# 2    -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
# 3    -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
# 4    -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
# ...        ...       ...       ...  ...       ...      ...       ...
# 2649  1.042701  0.847175 -0.152106  ...  4.393873 -0.36681 -0.302667
# 2650  1.565054  0.280123 -0.152106  ...  4.393873 -0.36681 -0.302667
# 2651 -0.524356  0.971218 -0.152106  ... -0.227590 -0.36681 -0.302667
# 2652  0.015408  0.553523 -0.152106  ... -0.227590 -0.36681 -0.302667
# 2653 -0.524356 -1.099535 -0.152106  ... -0.227590 -0.36681 -0.302667
#
#             33        34        35        36        37        38        39
# 0    -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
# 1    -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
# 2    -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
# 3    -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
# 4    -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
# ...        ...       ...       ...       ...       ...       ...       ...
# 2649  3.553890 -0.292664 -0.508623  3.814037  1.573157  1.209492  0.864376
# 2650 -0.281382 -0.292664 -0.508623 -0.262189  0.486338  1.209492  0.864376
# 2651  3.553890 -0.292664 -0.508623 -0.262189 -0.057072  1.209492  0.864376
# 2652 -0.281382 -0.292664 -0.508623 -0.262189  0.486338  1.209492  0.864376
# 2653 -0.281382 -0.292664 -0.508623 -0.262189 -0.600481 -0.826793 -1.156903
#
# [2654 rows x 40 columns]

# %% [markdown]
# ## Fitting the Random Forest Model

# %%
# Create a random forest instance and train it with the training data (`X_train_scaled` and `y_train`), define `n_estimators=500 (?)` and `random_state=72 (?)`.
# Create a random forest classifier
rf_model = RandomForestRegressor(n_estimators=500, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %% [markdown]
# ## Making Predictions Using the Random Forest Model

# %%
# Validate the trained model, by predicting loan defaults using the testing data (`X_test_scaled`).
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)
predictions
# Out:
# array([ 3.59387390e-03,  1.05135375e-02,  3.59387390e-03,  1.83724806e-02,
#         1.33917320e-02,  3.59387390e-03,  3.59387390e-03,  3.59387390e-03,
#         3.59387390e-03,  5.17706878e-02,  4.49361420e-02, -9.32144930e-04,
#         3.59387390e-03,  1.06477574e-02,  3.59387390e-03,  3.59387390e-03,
#         6.62845577e-03,  3.59387390e-03,  3.59387390e-03,  3.59387390e-03,
#         3.59387390e-03,  3.59387390e-03, -1.65082246e-02,  3.59387390e-03,
#         3.19329642e-03,  3.59387390e-03,  3.59387390e-03,  1.87516163e-03,
#         3.59387390e-03,  9.02287545e-03,  3.59387390e-03,  6.54922038e-02,
#         3.59387390e-03,  1.22182847e-02,  3.59387390e-03,  4.65360106e-02,
#         9.14894684e-03,  3.59387390e-03,  3.59387390e-03, -4.41958951e-03,
#         3.59387390e-03,  3.59387390e-03,  3.59387390e-03,  3.59387390e-03,
#        -6.59749628e-03,  3.59387390e-03,  7.00953613e-03,  3.59387390e-03,
#         3.59387390e-03,  3.75755157e-03,  8.44233184e-03,  3.59387390e-03,
#         3.59387390e-03,  6.27942789e-03, -6.38805848e-03,  3.59387390e-03,
#         4.28076517e-03,  8.87318209e-03,  1.30248391e-02,  6.67361454e-04,
#         3.59387390e-03, -9.60214858e-03,  1.34303643e-02,  3.59387390e-03,
#         3.59387390e-03,  3.59387390e-03,  2.91627198e-03,  3.59387390e-03,
#         2.90489233e-02,  3.59387390e-03,  3.59387390e-03,  2.21467084e-02,
#         3.59387390e-03,  1.27838216e-02,  3.59387390e-03,  2.23408867e-02,
#         3.59387390e-03,  3.86494646e-02, -8.37906903e-03,  3.59387390e-03,
#         3.59387390e-03, -6.36945802e-03,  1.01141518e-02,  2.49505276e-02,
#         3.59387390e-03,  1.92683838e-02, -8.78054650e-03,  3.59387390e-03,
#         7.36997120e-03,  3.59387390e-03,  3.59387390e-03,  4.18692016e-02,
#        -1.05915524e-02,  2.50424778e-03,  3.30626760e-02,  3.59387390e-03,
#         3.59387390e-03, -2.55992941e-03,  3.59387390e-03, -1.14208779e-02,
#         3.59387390e-03,  1.09276421e-02,  9.34365440e-03,  3.59387390e-03,
#         3.59387390e-03,  3.59387390e-03,
  3.59387390e-03,
#         3.59387390e-03,  3.59387390e-03,  2.15012831e-03, -1.81766965e-02,
#        -4.12241060e-03,  3.59387390e-03,  3.59387390e-03,  2.53197553e-03,
#         1.46809696e-02,  3.59387390e-03,  3.59387390e-03,  3.59387390e-03,
#         3.59387390e-03,  1.88646102e-02,  3.59387390e-03,  7.89578735e-03,
#         3.59387390e-03,  4.46443745e-02,  1.25598446e-02, -5.77095684e-03,
#         3.59387390e-03,  3.59387390e-03,  1.38502974e-02, -3.52087970e-03,
#         3.59387390e-03,  1.78218791e-03,  3.59387390e-03,  7.89968471e-03,
#        -8.52432359e-03, -3.73788837e-03,  2.44688311e-02,  3.59387390e-03,
#         2.52738872e-02,  1.87622153e-02,  3.59387390e-03, -2.84558584e-03,
#         8.57200480e-03,  5.10905056e-02,  3.59387390e-03,  2.39807798e-02,
#         3.59387390e-03,  6.55421282e-02,  3.59387390e-03,  7.33687426e-03,
#         3.53945490e-02,  3.59387390e-03, -4.12335017e-03,  4.46367742e-03,
#         3.46718519e-02,  1.58246068e-02, -2.73918862e-03,  3.59387390e-03,
#         3.59387390e-03,  1.52619800e-02,  2.09761957e-02,  1.40318350e-02,
#         3.59387390e-03,  3.59387390e-03,  1.37765286e-02,  1.31119285e-02,
#         4.60702108e-02,  9.20842087e-03,  1.88818364e-02,  3.59387390e-03,
#         8.86273994e-03,  8.26059135e-03,  3.59387390e-03, -1.45702948e-02,
#         1.63073356e-02,  3.59387390e-03, -5.60883912e-03,  5.19945250e-02,
#         3.59387390e-03,  8.32943121e-04,  1.72815890e-03,  3.59387390e-03,
#         3.59387390e-03,  3.59387390e-03,  4.75396280e-03,  3.59387390e-03])

# %% [markdown]
# ## Model Evaluation

# %%
# Calculating MSE
mse = mean_squared_error(y_test, predictions)
# Displaying results
print(mse)
# Out:
# 0.00564117805905732

# %%
predictions2 = rf_model.predict(X_train_scaled)
mse = mean_squared_error(y_train, predictions2)
# Displaying results
print(mse)
# Out:
# 0.002421640178791245

# %% [markdown]
# ## Feature Importance

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_

# %%
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.1299463968968181, 'number likes'),
#  (0.12228459904994497, 'number retweets clean'),
#  (0.11796785346541705, 'number replies'),
#  (0.11670817936653537, 'compound'),
#  (0.08903348914793531, 'positive'),
#  (0.08222923575921433, 'neutral'),
#  (0.07064815113826681, 'negative'),
#  (0.06612869665287407, 'tweet count'),
#  (0.026721951335278247, 'keyword strength'),
#  (0.02045353365758266, 'soon'),
#  (0.014154997318303993, 'next week'),
#  (0.012008971706699378, 'tesla'),
#  (0.01165722011952232, 'engine'),
#  (0.011215530787644873, 'production'),
#  (0.011138836024046188, 'sustainable energy'),
#  (0.010397119989198794, 'time'),
#  (0.007868752891282913, 'launch'),
#  (0.007531990675803026, 'rocket'),
#  (0.00723008521150641, 'spacex'),
#  (0.007118156377408219, 'starship'),
#  (0.005874381228900935, 'mars'),
#  (0.005574628739542636, 'coming soon'),
#  (0.0054273398051207416, 'giga berlin'),
#  (0.005040746883897979, 'self-driving'),
#  (0.004833496068155529, 'next year'),
#  (0.004208086714330796, 'solar power'),
#  (0.0032803580762017647, 'model 3'),
#  (0.003273536321918114, 'electric car'),
#  (0.0032011768950326765, 'keyword flag'),
#  (0.003023384137214775, 'software update'),
#  (0.0026610059432128335, 'falcon 9'),
#  (0.0025186019080764804, 'quarterly report announcement flag'),
#  (0.0016155390412978142, 'next month'),
#  (0.001605098715138084, 'model x'),
#  (0.0013708631700927508, 'space station'),
#  (0.0011881659003874618, 'dual motor'),
#  (0.0011035636900873515, 'sentiment'),
#  (0.000995299364112578, 'falcon heavy'),
#  (0.0007419643213352975, 'climate change'),
#  (1.901550466033528e-05, 'tweet flag')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='green', title= 'Features Importances', 
                        figsize=(20,30), legend=False, fontsize=30)

# %% [markdown]
# ---

# %%
new=pd.DataFrame()
new['y1']=dropped_na_df['Y_d1_pr_change_diff']
new['pct_change_tsla']=dropped_na_df['TSLA'].pct_change()
new['pct_change_qqq']=dropped_na_df['QQQ'].pct_change()
new
# Out:
#                   y1  pct_change_tsla  pct_change_qqq
# date
# 2010-07-07 -0.051168              NaN             NaN
# 2010-07-08  0.099604         0.105063        0.005459
# 2010-07-09 -0.012939        -0.003436        0.009502
# 2010-07-12 -0.023028        -0.020115        0.002913
# 2010-07-13  0.050969         0.063930        0.012961
# ...              ...              ...             ...
# 2021-01-13 -0.000902         0.005851        0.006753
# 2021-01-14 -0.005666        -0.011013       -0.005347
# 2021-01-15 -0.014375        -0.022296       -0.007921
# 2021-01-19  0.007670         0.022260        0.014590
# 2021-01-20 -0.016275         0.006986        0.023261
#
# [2654 rows x 3 columns]

# %%
new['Predicted Return'] = rf_model.predict(X_scaled)
new = new.iloc[1:, :]
new
# Out:
#                   y1  pct_change_tsla  pct_change_qqq  Predicted Return
# date
# 2010-07-08  0.099604         0.105063        0.005459          0.003594
# 2010-07-09 -0.012939        -0.003436        0.009502          0.003594
# 2010-07-12 -0.023028        -0.020115        0.002913          0.003594
# 2010-07-13  0.050969         0.063930        0.012961          0.003594
# 2010-07-14  0.088641         0.093716        0.005074          0.003594
# ...              ...              ...             ...               ...
# 2021-01-13 -0.000902         0.005851        0.006753          0.073398
# 2021-01-14 -0.005666        -0.011013       -0.005347          0.088399
# 2021-01-15 -0.014375        -0.022296       -0.007921         -0.022006
# 2021-01-19  0.007670         0.022260        0.014590          0.060694
# 2021-01-20 -0.016275         0.006986        0.023261          0.003594
#
# [2653 rows x 4 columns]

# %%
new['Signal'] = np.where(new['Predicted Return'] > 0.003594, 1.0, 0.0)
new['Signal'].value_counts()
# Out:
# C:\Users\Minyeong\.conda\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0.0    1773
# 1.0     880
# Name: Signal, dtype: int64

# %%
new.head()
# Out:
#                   y1  pct_change_tsla  pct_change_qqq  Predicted Return  \
# date
# 2010-07-08  0.099604         0.105063        0.005459          0.003594
# 2010-07-09 -0.012939        -0.003436        0.009502          0.003594
# 2010-07-12 -0.023028        -0.020115        0.002913          0.003594
# 2010-07-13  0.050969         0.063930        0.012961          0.003594
# 2010-07-14  0.088641         0.093716        0.005074          0.003594
#
#             Signal
# date
# 2010-07-08     0.0
# 2010-07-09     0.0
# 2010-07-12     0.0
# 2010-07-13     0.0
# 2010-07-14     0.0

# %%
# file_name="ML_algo.csv"
# output_file = Path(f"../Resources/{file_name}")
# new.to_csv(f"{output_file}")
